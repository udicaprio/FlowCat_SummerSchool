# %% [markdown]
# # Exercise 1 — Python basics for process intensification
#
# **Hands-on workbook**
#
# Download the repository, then upload this notebook and `process_intensification_data.csv` to Google Colab.
#
# This exercise introduces the Python tools that we will need in the machine-learning exercise. The examples use a small, synthetic process-intensification dataset.

# %% [markdown]
# ## Learning objectives
#
# By the end of this exercise, you should be able to:
#
# - run and edit cells in Google Colab;
# - store engineering values in variables and use conditions and loops;
# - define and call simple functions that return calculated values;
# - calculate with NumPy arrays;
# - inspect and select tabular data with pandas;
# - create and label simple plots with Matplotlib.
#
# > **Colab tip:** Run the current cell with `Shift + Enter`. Variables created by a cell remain available to cells run later. If the runtime is restarted, run the notebook again from the top.
#
# Complete the coding steps in order. During a taught session, follow the explanation provided by the instructor. For independent study, use the written instructions and consult the solution after attempting each step. When a cell contains a commented line with `...`, uncomment it and replace `...` with the required code.

# %% [markdown]
# ## 1. Basic Python
#
# A variable gives a name to a value. Python infers the value's type: text is a `str`, a whole number is an `int`, a decimal is a `float`, and `True` or `False` is a `bool`. Create the string `"Intensified reactor"` and a list containing the residence times `3.2`, `4`, and `6` minutes.

# %%
#TO DO
#Generate a string containing the reactor name "Intensified reactor"
#reactor_name = ...
temperature_C = 60.0
residence_time_min = 10
target_reached = True

#TO DO
#Generate a list with residence times 3.2, 4, and 6 minutes
#residence_times_min = ...

print(reactor_name)
print(residence_times_min)
print(temperature_C, type(temperature_C))
print(residence_time_min, type(residence_time_min))
print(target_reached, type(target_reached))

# %% [markdown]
# ### Step 1 — Make a calculation
#
# Convert `temperature_C` to kelvin and store the result in `temperature_K`.
#
# $$T_K = T_{°C} + 273.15$$

# %%
#TO DO
#Use temperature_C and add 273.15 to convert the temperature to kelvin
#temperature_K = ...
print("Operating temperature:", temperature_K, "K")

# %% [markdown]
# ### Step 2 — Use a conditional statement
#
# Print `The conversion target is reached.` when `conversion_percent` is greater than or equal to `target_conversion_percent`. Otherwise, report that it is not reached. Indentation is part of Python's syntax.

# %%
conversion_percent = 82.6
target_conversion_percent = 80.0

#TO DO
#Compare conversion_percent with target_conversion_percent using >=
#Print "The conversion target is reached." when the condition is true
#Otherwise, print "The conversion target is not reached."

# %% [markdown]
# ### Step 3 — Store several values and repeat an action
#
# A list stores an ordered collection. Complete the loop so it prints each residence time and its space velocity, $1/\tau$.

# %%
for residence_time in residence_times_min:
    #TO DO
    #Use residence_time from residence_times_min and calculate 1 / residence_time
    #Store the result in space_velocity_per_min and print both values with their units
    pass

# %% [markdown]
# ### Step 4 — Define and call functions
#
# A function groups instructions under a reusable name. First, examine and run an example that adds two numbers. Then, create and call a function that calculates the mean, minimum, and maximum of a list.

# %%
def add_numbers(first_number, second_number):
    result = first_number + second_number
    return result

addition_result = add_numbers(4, 6)
print("Addition result:", addition_result)

#TO DO
#Create calculate_statistics(values) to calculate the mean, minimum, and maximum of values
#Suggestion: return mean_value, minimum_value, and maximum_value
#Call the function using residence_times_min and store the results in mean_residence_time, minimum_residence_time, and maximum_residence_time

# %% [markdown]
# ## 2. Numerical calculations with NumPy
#
# NumPy provides fast operations on arrays. Unlike a Python list, a NumPy array can perform the same calculation on all its values at once. The conventional and intensified reactor were evaluated at five temperatures. Create the intensified-reactor conversion array from `[66.8, 75.2, 82.6, 88.1, 91.7]`.

# %%
import numpy as np

temperatures_C = np.array([40, 50, 60, 70, 80])
conversion_conventional = np.array([54.1, 62.4, 70.8, 77.5, 82.1])
#TO DO
#Use np.array to generate conversion_intensified from [66.8, 75.2, 82.6, 88.1, 91.7]
#conversion_intensified = ...

print(temperatures_C)
print(temperatures_C.shape)
print(conversion_intensified)

# %% [markdown]
# ### Step 5 — Perform element-wise operations
#
# 1. Subtract the conventional conversion from the intensified conversion.
# 2. Divide the intensified percentages by 100 to obtain fractions.

# %%
#TO DO
#Subtract conversion_conventional from conversion_intensified at each temperature
#conversion_improvement = ...
#Divide conversion_intensified by 100 to convert the percentages to fractions
#conversion_fraction = ...

print("Improvement in percentage points:", conversion_improvement)
print("Conversion as a fraction:", conversion_fraction)

# %% [markdown]
# ### Step 6 — Summarize an array
#
# Use `np.mean`, `np.min`, `np.max`, and `np.std` to summarize `conversion_intensified`.

# %%
#TO DO
#Use conversion_intensified with np.mean, np.min, np.max, and np.std
#mean_conversion = ...
#minimum_conversion = ...
#maximum_conversion = ...
#std_conversion = ...

print("Mean:", mean_conversion)
print("Minimum:", minimum_conversion)
print("Maximum:", maximum_conversion)
print("Standard deviation:", std_conversion)

# %% [markdown]
# ### Step 7 — Work with a two-dimensional array
#
# Rows represent reactor types and columns represent temperatures. Calculate:
#
# - one mean at each temperature using `axis=0`;
# - one mean for each reactor using `axis=1`.
#
# The axis is the dimension that NumPy *reduces*.

# %%
conversion_matrix = np.array([
    conversion_conventional,
    conversion_intensified,
])

#TO DO
#Use np.mean on conversion_matrix with axis=0 to calculate one mean at each temperature
#mean_at_each_temperature = ...
#Use np.mean on conversion_matrix with axis=1 to calculate one mean for each reactor
#mean_for_each_reactor = ...

print("Matrix shape:", conversion_matrix.shape)
print("Mean at each temperature:", mean_at_each_temperature)
print("Mean for each reactor:", mean_for_each_reactor)

# %% [markdown]
# `np.linspace(start, stop, number)` is useful for defining evenly spaced operating conditions. Run this example and change the number of temperatures.

# %%
temperature_grid_C = np.linspace(40, 80, 9)
print(temperature_grid_C)

# %% [markdown]
# ## 3. Tabular data with pandas
#
# A pandas `DataFrame` represents a table. Each row is one observation and each column is one variable. Before running the next cell, upload `process_intensification_data.csv` to the Google Colab session using the **Files** panel on the left. Then create the DataFrame using `pd.read_csv()`.
#
# > **Data disclaimer:** These data are synthetic and illustrate plausible trends only. They are not suitable for research, process design, safety decisions, or commercial use.

# %%
import pandas as pd

#TO DO
#Use pd.read_csv to load "process_intensification_data.csv" into a DataFrame named df
#df = ...
print("Dataset loaded successfully.")

# %% [markdown]
# ### Step 8 — Inspect the dataset
#
# Use `head()` to show the first five rows and check that the file was loaded correctly.

# %%
#TO DO
#Use df.head() to show the first five rows of df

# %% [markdown]
# Use `shape` to determine how many rows and columns are present.

# %%
#TO DO
#Use df.shape to print the number of rows and columns in df

# %% [markdown]
# Use `columns` to inspect the column names.

# %%
#TO DO
#Use df.columns to print the column names of df

# %% [markdown]
# Use `describe()` to inspect summary statistics. Which columns are numerical? What is the largest conversion?

# %%
#TO DO
#Use df.describe() to show summary statistics for the numerical columns of df

# %% [markdown]
# ### Step 9a — Select one column
#
# Select the `temperature_C` column with `df["column_name"]`.

# %%
#TO DO
#Use df and select the "temperature_C" column, then store it in temperatures
#temperatures = ...
print(temperatures)

# %% [markdown]
# ### Step 9b — Select several columns
#
# Select `reactor_type`, `temperature_C`, and `conversion_percent` together by passing a list of names.

# %%
#TO DO
#Use df and select ["reactor_type", "temperature_C", "conversion_percent"]
#Store the resulting DataFrame in selected_columns
#selected_columns = ...
print(selected_columns)

# %% [markdown]
# ### Step 9c — Select one row
#
# Select the fourth row with `iloc`. Remember that Python starts counting from zero.

# %%
#TO DO
#Use df.iloc[3] to select the fourth row of df and store it in fourth_row
#fourth_row = ...
print(fourth_row)

# %% [markdown]
# ### Step 10 — Filter observations
#
# Keep only intensified-reactor runs with at least 85% conversion. Use `&` to require both conditions.

# %%
#TO DO
#Use df and select rows where reactor_type is "Intensified"
#Also require conversion_percent to be greater than or equal to 85 using &
#Store the selected rows in high_conversion_runs
#high_conversion_runs = ...
print(high_conversion_runs)

# %% [markdown]
# ## 4. Data visualization with Matplotlib
#
# Plots make patterns and unusual observations easier to see. Every engineering plot should identify the variables and units on both axes. Start by importing `pyplot` from Matplotlib with the alias `plt`.

# %%
#TO DO
#Import pyplot from Matplotlib using the alias plt
#from matplotlib import pyplot as ...

# %% [markdown]
# ### Step 11 — Create a scatter plot
#
# Plot `conversion_percent` against `residence_time_min`. Add axis labels with units, a title, and a grid.

# %%
#TO DO
#Use plt.scatter with df["residence_time_min"] on the x-axis
#Use df["conversion_percent"] on the y-axis and set alpha=0.75
#Add the x-label "Residence time [min]" and y-label "Conversion [%]"
#Add the title "Conversion versus residence time" and a grid with alpha=0.25
plt.show()

# %% [markdown]
# ### Step 12 — Compare reactor types
#
# The loop below creates one group at a time. Inside it, plot each group's residence time and conversion and assign `label=reactor_type`. Add a legend after the loop.

# %%
for reactor_type, group in df.groupby("reactor_type"):
    #TO DO
    #Use plt.scatter with group["residence_time_min"] and group["conversion_percent"]
    #Use label=reactor_type and alpha=0.8 for each group
    pass

#TO DO
#Add the x-label "Residence time [min]" and y-label "Conversion [%]"
#Add the title "Reactor comparison", the legend, and a grid with alpha=0.25
plt.show()

# %% [markdown]
# ### Step 13 — Plot a distribution
#
# Create a histogram of `conversion_percent` using `plt.hist`. Label both axes.

# %%
#TO DO
#Use plt.hist with df["conversion_percent"], bins=8, and edgecolor="black"
#Add the x-label "Conversion [%]" and y-label "Number of runs"
#Add the title "Distribution of conversion"
plt.show()

# %% [markdown]
# ## Concluding analysis and interpretation
#
# Find the run with the highest conversion among those using less than 450 kJ/kg. Suggested steps:
#
# 1. filter `specific_energy_kJ_kg`;
# 2. find the index of the largest conversion with `idxmax()`;
# 3. select that row with `.loc[index]`.
#
# Then explain in one sentence why selecting the highest conversion alone may not identify the best process.

# %%
#TO DO
#Use df to select rows where specific_energy_kJ_kg is less than 450
#Store the selected rows in energy_limited_runs
#Use energy_limited_runs["conversion_percent"].idxmax() to obtain best_index
#Use energy_limited_runs.loc[best_index] to obtain best_run and print best_run
#Print a sentence explaining why conversion must be considered with other process constraints
